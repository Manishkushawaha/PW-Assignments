# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a popular Python library used for creating high-quality visualizations and plots. It provides a variety of functions and tools for creating different types of plots, charts, and graphs.
#
# Matplotlib is used because it offers a wide range of customization options and flexibility in creating plots, making it suitable for both simple and complex visualizations. It also has a large community of users and developers, which means there is a wealth of resources available for learning and troubleshooting.
#
# Here are five types of plots that can be plotted using the Pyplot module of Matplotlib:
#
# Line plot: A line plot is a basic plot that displays data as a series of points connected by lines.
#
# Scatter plot: A scatter plot is a plot that displays the relationship between two variables as a collection of points on a 2D plane.
#
# Histogram: A histogram is a plot that shows the distribution of a dataset by grouping the data into bins and displaying the frequency of data points in each bin.
#
# Bar plot: A bar plot is a plot that displays the comparison of values across different categories using bars.
#
# Pie chart: A pie chart is a plot that shows the proportion of different categories in a dataset as slices of a pie.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Ans: A scatter plot is a type of plot that displays the relationship between two variables as a collection of points on a 2D plane. Each point on the plot represents the value of the two variables for a single data point.

# %%
import matplotlib.pyplot as plt

import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x,y)

plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans: The subplot() function in Matplotlib is used to create multiple plots in a single figure. It takes three arguments: the number of rows, the number of columns, and the index of the current plot. By specifying the index, you can create and modify individual subplots in the figure.

# %%
import matplotlib.pyplot as plt

import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60]) 

x4 = np.array([0, 1, 2, 3, 4, 5])  
y4 = np.array([200, 350, 250, 550, 450, 150])
    
plt.subplot(2,2,1)  
plt.plot(x1,y1)
plt.title('Line Plot 1')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')


plt.subplot(2,2,2)  
plt.plot(x2,y2)
plt.title('Line Plot 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')


plt.subplot(2,2,3)  
plt.plot(x3,y3)
plt.title('Line Plot 3')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')


plt.subplot(2,2,4)  
plt.plot(x4,y4)
plt.title('Line Plot 4')

plt.tight_layout()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans: A bar plot is a type of plot that displays data using rectangular bars, where the height or length of each bar represents the magnitude of the data being plotted. Bar plots are useful for comparing the relative magnitudes of different categories or groups of data, and they can be used to show trends or changes over time.

# %%
import matplotlib.pyplot as plt
import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


plt.bar(company, profit,color = 'g')
plt.title('Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

plt.barh(company, profit,color='r')
plt.title('Company Profits')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans: A box plot, also known as a box-and-whisker plot, is a statistical visualization tool that displays the distribution of a dataset using a box and whiskers. The box represents the interquartile range (IQR), which contains the middle 50% of the data, and the whiskers represent the range of the data that falls within 1.5 times the IQR. Any points outside of the whiskers are considered outliers.
#
# Box plots are useful for quickly identifying the central tendency, spread, and skewness of a dataset. They can also be used to compare the distributions of multiple datasets side-by-side.

# %%
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1,box2])

plt.title('Box Plot')
plt.xlabel('Box')
plt.ylabel('Value')

plt.show()
